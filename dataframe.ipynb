# %%
import pandas as pd

# %%
df = pd.read_csv('animals.csv', encoding='ISO-8859-1', skiprows=2)
df = df.drop(df.columns[[4,5,6,7,9,10]], axis='columns')
df = df.dropna()
df
# Out:
#                                             Nom commun  \
# 0    Salamandre sombre des montagnes (Population ca...
# 1    Salamandre sombre des montagnes (Population de...
# 2                                          Scolopendre
# 3        Martre d'Amérique (Population de Terre-Neuve)
# 4                                Carmantine d'Amérique
# ..                                                 ...
# 274                         Stylophore à deux feuilles
# 275                                     Lampsile jaune
# 276  Violette jaune des monts de la sous-espèce pra...
# 277       Paruline polyglotte de la sous-espèce virens
# 278                                    Teigne du yucca
#
#                    Nom scientifique            Groupe d'espèces  \
# 0          Desmognathus ochrophaeus                   Amphibien
# 1          Desmognathus ochrophaeus                   Amphibien
# 2           Asplenium scolopendrium  Plante vasculaire, fougère
# 3           Martes americana atrata                   Mammifère
# 4                Justicia americana    Plante vasculaire, herbe
# ..                              ...                         ...
# 274           Stylophorum diphyllum    Plante vasculaire, herbe
# 275               Lampsilis cariosa                     Mollusc
# 276  Viola praemorsa ssp. praemorsa    Plante vasculaire, herbe
# 277           Icteria virens virens                      Oiseau
# 278           Tegeticula yuccasella                     Insecte
#
#     Désignation de la Loi sur les espèces en péril  \
# 0                           En voie de disparition
# 1                                          Menacée
# 2                                     Préoccupante
# 3                                          Menacée
# 4                                          Menacée
# ..                                             ...
# 274                         En voie de disparition
# 275                                   Préoccupante
# 276                         En voie de disparition
# 277                         En voie de disparition
# 278                         En voie de disparition
#
#                                Données sur les espèces
# 0    Probablement moins de 100 individus matures, r...
# 1        Probablement moins de 1000 individus matures.
# 2    La taille de la population canadienne est éval...
# 3    La population de la Martre dAmérique a été es...
# 4    Il y a 13 sous-populations existantes connues....
# ..                                                 ...
# 274  Les 3 populations canadiennes connues renferma...
# 275  Les tendances de la taille des populations son...
# 276  Plusieurs populations ont disparu en raison du...
# 277  Il y a moins de 42 paires en Ontario. La popul...
# 278  Les données démographiques portent sur le cour...
#
# [279 rows x 5 columns]
